# %% [markdown]
# <h1>Clase del 03 de Septiembre del 2024</h1>

# %% [markdown]
# --> Conjunto de datos: Son los datos que se obtienen y que aparecen en la grafica....
#
# --> Regresión Lineal: f(x) = m.x + b
#
#     Definición: La regresión lineal es una técnica de análisis de datos que predice el valor de datos desconocidos mediante el uso de otro valor de datos relacionado y conocido. Modela matemáticamente la variable desconocida o dependiente y la variable conocida o independiente como una ecuación lineal.
#
# Librerias:
#     <p>Numpy: Para las matrices</p>
#     <p>Scikit Learn: Para la regresion</p>
#     <p>Matplotlib: Graficar</p>
#
# <h3> La correlaccion es mayor si esta mas cerca a 1 y a -1. </h3>

# %%
import matplotlib.pyplot as plt

x = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]
y = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]


plt.scatter(x, y) # Un diagrama de dispersión de x vs y.

plt.show() #Mostrar todas las figuras abiertas.

# %% [markdown]
# --> Regresión Lineal: f(x) = m.x + b

# %%
import matplotlib.pyplot as plt
from scipy import stats


x = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]
y = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]

# Ejecuta un metodo que devuelve algunos valores clave importantes de la Regresion lineal
# slope (pendiente), intercept (interseccion en el eje y), r (coeficiente de correlacion), p (valor p) y std_err (error estandar de la pendiente)
slope, intercept, r, p, std_err = stats.linregress(x, y)

# Crea una funcion que utilice los valores de pendiente e intercepto para devolver un nuevo valor. Este valor representa donde en el eje y se corta
# Se define una fncion llamada myfunc(x) que calcula el valor predicho de y basado en la pendiente y la interseccion obtenidas de la regresion lineal.
def myfunc(x):
    return slope * x + intercept


# Calcular los valores del modelo para cada punto de datos en x:
# Se aplica la funcion myfunc a cada valor en la lista x para calcular los valores correspondientes en mymodel. Esto representa la linea de regresion
mymodel = list(map(myfunc, x ))

# Crear un gráfico de dispersión (scatter plot) y traza la línea de regresión:
# Se crea un gráfico de dispersión con los puntos de datos originales utilizando plt.scatter(x, y).
# Luego, se traza la línea de regresión utilizando plt.plot(x, mymodel).
# Finalmente, se muestra el gráfico resultante utilizando plt.show().
plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()
print(r)
# Out:
# -0.758591524376155

# %%
from scipy import stats

x = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]
у = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]

slope, intercept, r, P, std_err = stats.linregress(x, y)

def myfunc(x):
    return slope * x + intercept

speed = myfunc (14)

print(speed)
# Out:
# 78.5879323031641

# %% [markdown]
# <h3> Ejemplo 2: </h3>

# %%
import matplotlib.pyplot as plt
from scipy import stats


x = [2, 4, 8, 7, 6, 10, 25, 2, 5, 1, 5, 12]
y = [50, 25, 13, 26, 57, 12, 25, 200, 15, 16, 17, 8]

# Ejecuta un metodo que devuelve algunos valores clave importantes de la Regresion lineal
# slope (pendiente), intercept (interseccion en el eje y), r (coeficiente de correlacion), p (valor p) y std_err (error estandar de la pendiente)
slope, intercept, r, p, std_err = stats.linregress(x, y)

# Crea una funcion que utilice los valores de pendiente e intercepto para devolver un nuevo valor. Este valor representa donde en el eje y se corta
# Se define una fncion llamada myfunc(x) que calcula el valor predicho de y basado en la pendiente y la interseccion obtenidas de la regresion lineal.
def myfunc(x):
    return slope * x + intercept


# Calcular los valores del modelo para cada punto de datos en x:
# Se aplica la funcion myfunc a cada valor en la lista x para calcular los valores correspondientes en mymodel. Esto representa la linea de regresion
mymodel = list(map(myfunc, x ))

# Crear un gráfico de dispersión (scatter plot) y traza la línea de regresión:
# Se crea un gráfico de dispersión con los puntos de datos originales utilizando plt.scatter(x, y).
# Luego, se traza la línea de regresión utilizando plt.plot(x, mymodel).
# Finalmente, se muestra el gráfico resultante utilizando plt.show().
plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()
print(r)
# Out:
# -0.29617492888648234

# %% [markdown]
# <h3> Ejemplo 2: </h3>

# %%
import matplotlib.pyplot as plt
from scipy import stats

x = [89, 43, 36, 36, 95, 10, 66, 34, 38, 20, 26, 29, 48, 64, 6, 5, 36, 66, 72, 40]
y = [21, 46, 3, 35, 67, 95, 53, 72, 58, 10, 26, 34, 90, 33, 38, 20, 56, 2, 47, 15]

slope, intercept, r, P, std_err = stats. linregress(x, y)

def myfunc (x) :
    return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()
print(r)
# Out:
# 0.013318141542974915

# %%
import matplotlib.pyplot as plt 
import numpy as np
from sklearn import datasets, linear_model, model_selection


X, y = datasets.load_diabetes(return_X_y=True) #Cargar el conjunto de datos de diabetes y separarlo en caracteristicas (X)y objetiv

# Lo que recibes como respuesta es una tupla.Lo que estas haciendo es asignar los dos primeros valores de la tupla a X e y respectiv
print(X.shape) # Imprimir la estructura del conjunto de datos y el primer punto de datos como referencia
print(X[0])

#Piensa un poco en la relacion entre los datos y el objetivo de la regresion.La regresion lineal predice relaciones entre la caracte

X = X[:, 2] # Seleccionar solo la tercera caracteristica (IMC) para simplificar

# Calcular la correlación entre el IMC y la progresión de la enfermedad
correlacion = np.corrcoef(X, y)[0, 1]
print(f'La correlación entre el IMC y la progresión de la enfermedad es: {correlacion:.2f}')

X = X.reshape((-1,1)) # Cambiar X para que sea una matriz 2D como requiere scikit-learn

# Ahora que tiene los datos listos para ser representados,puede ver si una maquina puede ayudar a determinar una division logica entr
# Para ello,es necesario dividir los datos (X)y el objetivo (y)en conjuntos de prueba y de entrenamiento.Scikit-learn tiene una fo

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.33) # Dividir los datos en conjuntos de entrena


model = linear_model.LinearRegression() # Creacion de un modelo de regresion lineal

model.fit(X_train, y_train) #Entrenar el modelo utilizando los datos de entrenamiento

y_pred = model.predict(X_test) # Prediccion de los valores objetivo para los datos de prueba

plt.scatter(X_test, y_test, color='black') #Trazado de los puntos de los datos de prueba

plt.plot(X_test, y_pred, color='blue', linewidth=3) # Trazado de la linea de regresion

#Añadir etiquetas y titulo al gráfico
plt.xlabel("IMC escalado")
plt.ylabel("Progresión de la enfermedad")
plt.title("Grafico que observa la progresion de la diabetes frente al IMC")
plt.show()



# Supongamos que quieres predecir la progresion de la enfermedad para un BMI escalado de 0.05
nuevo_valor = np.array([[0.05]])

# Utiliza el modelo entrenado para predecir el valor
prediccion = model.predict(nuevo_valor)

#Imprime la prediccion
print(f'La predicción para un BMI escalado de 0.05 es: {prediccion[0]}')
# Out:
# (442, 10)
# [ 0.03807591  0.05068012  0.06169621  0.02187239 -0.0442235  -0.03482076
#  -0.04340085 -0.00259226  0.01990749 -0.01764613]
# La correlación entre el IMC y la progresión de la enfermedad es: 0.59
# La predicción para un BMI escalado de 0.05 es: 198.38139780520166

# %% [markdown]
# <h2> Regresión Polinómica </h2>
